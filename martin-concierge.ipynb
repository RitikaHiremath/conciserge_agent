# %%
import os
from kaggle_secrets import UserSecretsClient

try:
    GOOGLE_API_KEY = UserSecretsClient().get_secret("GOOGLE_API_KEY")
    os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
    print("✅ Gemini API key setup complete.")
except Exception as e:
    print(
        f"🔑 Authentication Error: Please make sure you have added 'GOOGLE_API_KEY' to your Kaggle secrets. Details: {e}"
    )
# Out:
# ✅ Gemini API key setup complete.

# %%
from google.adk.agents import Agent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.tools import google_search, AgentTool, FunctionTool
from google.adk.sessions import InMemorySessionService
from google.genai import types
from google.adk.agents import ParallelAgent, SequentialAgent
from google.adk.sessions import InMemorySessionService
from google.adk.runners import Runner
from google.genai import types

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %%
retry_config=types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1, # Initial delay before first retry (in seconds)
    http_status_codes=[429, 500, 503, 504] # Retry on these HTTP errors
)

# %%
def make_booking(place: str, date: str, time: str) -> str:
    """Make a booking at a specified place, date, and time."""
    return f"✅ Booking confirmed at {place} on {date} at {time}"

booking_tool = FunctionTool(make_booking)

# %%
def get_location_context(location: str = None) -> str:
    """Get contextual information about a location (simulated MCP tool)."""
    if not location:
        return "Please specify a location to get information about."
    
    # This would connect to a real MCP server in production
    location_info = {
        "weather": "Typically varies by season",
        "timezone": "Local time",
        "currency": "Local currency", 
        "language": "Local language",
        "emergency": "Local emergency numbers"
    }
    
    return f"📍 Location context for {location}: {location_info}"

location_tool = FunctionTool(get_location_context)

# %%
booking_agent = Agent(
    name="booking_agent",
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    instruction="""You are a booking concierge agent. Your role is to:
- Help users make reservations and bookings
- Ask for missing information (place, date, time)
- Confirm booking details before proceeding
- Use the make_booking tool when all information is available
- Be friendly and professional""",
    tools = [make_booking]
)
info_agent = Agent(
    name="info_agent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are an information concierge agent. Your role is to:
- Provide accurate, up-to-date information about places, services, and general knowledge
- Use Google Search to find current information when needed
- Present information in a clear, organized manner
- Cite sources when using searched information""",
    tools = [google_search]
)

recommendation_agent = Agent(
    name="recommendation_agent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a recommendation concierge agent. Your role is to:
- Recommend activities, places, restaurants, hotels, etc.
- Provide personalized suggestions based on user preferences
- Consider factors like budget, location, and interests
- Use Google Search to find current recommendations
- Provide multiple options when possible""",
    tools = [google_search]
)

# %%
router_agent = Agent(
    name="router",
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    instruction="""You are the concierge router. Your responsibilities:

1. GREETING: If the user is starting a new conversation, give a warm welcome:
   "Hello! I'm Martin, your personal concierge. How can I assist you today? I can help with bookings, information, or recommendations!"

2. ROUTING: Analyze the user's request and categorize it as:
   - "booking": For making reservations, appointments, bookings
   - "information": For factual questions, details about places/services
   - "recommendation": For suggestions on what to do, where to go, etc.

3. CONTEXT: Maintain conversation context and be conversational.

Examples:
- "I want to book a table" → "booking"
- "Tell me about Paris" → "information" 
- "What should I do in Tokyo?" → "recommendation"
- "Hi" → greeting + ask how to help

Always respond naturally while categorizing the request.""",
    output_key="task_type"
)
distributor_agent = Agent(
    name="distributor",
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    instruction="""Based on the task type from the router, handle the request appropriately: {task_type}

If it's a greeting or general conversation, respond warmly and helpfully.
If it requires specialized assistance, route to the appropriate agent.

Remember: You are Martin the Concierge - be professional, friendly, and maintain conversation flow.""",
    tools=[AgentTool(recommendation_agent),AgentTool(booking_agent),AgentTool(info_agent), google_search] 
)

# %%
workers = ParallelAgent(
    name="workerGroup",
    sub_agents=[booking_agent, info_agent, recommendation_agent]
)

# %%
concierge_agent = SequentialAgent(
    name="martin_concierge",
    sub_agents=[router_agent, distributor_agent],
    instruction="""You are Martin, a professional concierge assistant. You provide:
- Booking services (restaurants, hotels, appointments)
- Information services (facts, details, current info) 
- Recommendation services (suggestions, ideas, plans)
- Location-based assistance

Always be polite, professional, and maintain conversation context. Remember user preferences and previous interactions.""",
    tools=[booking_tool, google_search, location_tool]
)

# %%
APP_NAME = "martin_concierge"
USER_ID = "user_001"

session_service = InMemorySessionService()

runner = Runner(
    agent=concierge_agent, 
    app_name=APP_NAME, 
    session_service=session_service
)

print("✅ Martin Concierge Agent initialized!")
print("   - Name: Martin Concierge")
print("   - Capabilities: Booking, Information, Recommendations")
print("   - Features: Context memory, Location awareness, Web search")
# Out:
# ✅ Martin Concierge Agent initialized!
#    - Name: Martin Concierge
#    - Capabilities: Booking, Information, Recommendations
#    - Features: Context memory, Location awareness, Web search

# %%
async def run_concierge_session(
    runner_instance: Runner,
    user_queries: list[str] | str = None,
    session_name: str = "concierge_chat",
):
    print(f"\n{'='*60}")
    print(f"🤵 Martin Concierge - Session: {session_name}")
    print(f"{'='*60}")
    
    # Get app name from the Runner
    app_name = runner_instance.app_name

    # Attempt to create a new session or retrieve an existing one
    try:
        session = await session_service.create_session(
            app_name=app_name, user_id=USER_ID, session_id=session_name
        )
        print("🌟 New session started!")
    except:
        session = await session_service.get_session(
            app_name=app_name, user_id=USER_ID, session_id=session_name
        )
        print("📖 Continuing existing session...")

    # Process queries if provided
    if user_queries:
        # Convert single query to list for uniform processing
        if type(user_queries) == str:
            user_queries = [user_queries]

        # Process each query in the list sequentially
        for query in user_queries:
            print(f"\n👤 You: {query}")

            # Convert the query string to the ADK Content format
            query_content = types.Content(role="user", parts=[types.Part(text=query)])

            # Stream the agent's response asynchronously
            async for event in runner_instance.run_async(
                user_id=USER_ID, session_id=session.id, new_message=query_content
            ):
                # Check if the event contains valid content
                if event.content and event.content.parts:
                    # Filter out empty or "None" responses before printing
                    if (
                        event.content.parts[0].text != "None"
                        and event.content.parts[0].text
                    ):
                        print(f"🤵 Martin: {event.content.parts[0].text}")
    else:
        print("No queries provided!")
    
    print(f"\n{'='*60}")

# %%
# Test realistic concierge scenarios
print("Testing Martin Concierge with realistic scenarios...")

await run_concierge_session(
    runner,
    [
        "Hi Martin, I need help with bookings",
        "I want to book a hotel in Paris for 3 nights next week",
        "Also need a restaurant reservation for a romantic dinner",
        "What are some good areas to stay in Paris?",
        "What are the best sites to visit nearby?"
    ],
    "paris_trip_help",
)
# Out:
# Testing Martin Concierge with realistic scenarios...
#
# ============================================================
# 🤵 Martin Concierge - Session: paris_trip_help
# ============================================================
# 🌟 New session started!
#
# 👤 You: Hi Martin, I need help with bookings
# 🤵 Martin: Okay, I can help you with bookings. What would you like to book?
# 🤵 Martin: Hi Martin, I need help with bookings.
# call booking_agent
# 🤵 Martin: Hello! I'm ready to help you with your bookings. What can I assist you with today?
# 🤵 Martin: Hello! I'm happy to help you with your bookings. What would you like to book?
# 🤵 Martin: I can help you with bookings. What would you like to book?
#
# 👤 You: I want to book a hotel in Paris for 3 nights next week
# 🤵 Martin: call booking_agent
# 🤵 Martin: I can help you with that. What dates would you like to book your stay for?
# 🤵 Martin: Great! To help me book your hotel in Paris, could you please provide me with the exact dates for your 3-night stay next week?
# 🤵 Martin: Great! Paris is a wonderful choice. To help me find the best hotel for you, could you please tell me your preferred check-in date for next week?
#
# 👤 You: Also need a restaurant reservation for a romantic dinner
# 🤵 Martin: call booking_agent
# 🤵 Martin: I can help you with that. What dates and times would you like for your restaurant reservation? Also, what is the desired cuisine?
# 🤵 Martin: I can certainly help with that! To make sure I find the perfect spot for your romantic dinner, could you tell me:
#
# *   What is your preferred date and time for the reservation?
# *   Do you have any specific cuisine preferences?
# *   What is your budget per person, if any?
# 🤵 Martin: That's a wonderful idea! Paris is renowned for its romantic dining experiences. To help me find the perfect spot, could you tell me a bit more about what you envision for this romantic dinner? For example:
#
# *   **What kind of cuisine are you in the mood for?** (e.g., French, Italian, something else?)
# *   **Do you have a preferred neighborhood or area in Paris?**
# *   **What's your approximate budget per person?**
# *   **Are there any specific features you'd like, such as a view (Eiffel Tower, Seine river), a quiet and intimate atmosphere, or live music?**
#
# Once I have a better understanding of your preferences, I can start looking for suitable restaurants.
#
# 👤 You: What are some good areas to stay in Paris?
# 🤵 Martin: I can help you with that! To recommend some good areas to stay in Paris, could you tell me a bit about what you're looking for in a neighborhood? For example, are you interested in:
#
# *   **A lively atmosphere with lots of restaurants and nightlife?**
# *   **A quieter, more residential feel?**
# *   **Proximity to specific attractions (like museums, Eiffel Tower, etc.)?**
# *   **A particular budget range?**
# 🤵 Martin: call recommendation_agent
# 🤵 Martin: I can help you with that! To recommend some good areas to stay in Paris, could you tell me a bit about what you're looking for in a neighborhood? For example, are you interested in:
#
# *   **A lively atmosphere with lots of restaurants and nightlife?**
# *   **A quieter, more residential feel?**
# *   **Proximity to specific attractions (like museums, Eiffel Tower, etc.)?**
# *   **A particular budget range?**
# 🤵 Martin: Paris offers a diverse range of neighborhoods, each with its own unique charm and appeal. To help you choose the best area to stay, consider what you're looking for:
#
# **For a central location with easy access to major attractions:**
#
# *   **The 1st Arrondissement (around the Louvre):** This is a fantastic area for first-time visitors, offering proximity to the Louvre Museum, Tuileries Garden, and other iconic landmarks. It's well-connected by metro and many sights are within walking distance.
# *   **Le Marais (3rd and 4th Arrondissements):** This historic and vibrant neighborhood is known for its charming streets, boutiques, art galleries, great restaurants, and lively bars. It's a great base for exploring and is considered quite central.
#
# **For a romantic atmosphere and charming streets:**
#
# *   **Montmartre (18th Arrondissement):** This area offers a village-like feel with cobblestone streets, artistic history, and stunning views of the city from the Sacré-Cœur Basilica. It's particularly recommended for couples.
# *   **Le Marais (3rd and 4th Arrondissements):** Its historic charm, architecture, and lively yet intimate feel make it a lovely choice for couples.
#
# **For proximity to the Eiffel Tower:**
#
# *   **The 7th Arrondissement:** This upscale neighborhood is home to the Eiffel Tower, as well as world-class museums like the Musée d'Orsay and Musée Rodin. It offers beautiful streets and good restaurants.
#
# **For a lively atmosphere with nightlife and dining:**
#
# *   **The Marais (3rd and 4th Arrondissements):** This area is packed with good shops, bars, restaurants, and cafes, offering a dynamic atmosphere.
# *   **Bastille (around Place de la Bastille):** Known for its lively nightlife, this area has a mix of cafes, nightclubs, and music venues, particularly appealing to those in their 20s.
# *   **Pigalle (9th Arrondissement):** While once known for its red-light district, Pigalle is now a popular spot for nightlife with many bars, clubs, and late-night eateries.
#
# **For a quieter, more local feel:**
#
# *   **The 20th Arrondissement:** This bohemian area offers a more local experience with contemporary art galleries and street art.
# *   **The 13th Arrondissement:** This district offers a mix of modern and old, and is generally quieter than the central tourist areas, making it ideal for those seeking a less touristy experience.
#
# If you can tell me more about your preferences, such as your budget, what kind of activities you're most interested in, or the general vibe you're looking for, I can provide a more tailored recommendation!
# 🤵 Martin: Paris offers a diverse range of neighborhoods, each with its own unique charm and appeal. To help you find the best area to stay, consider what you're looking for in a neighborhood:
#
# **For a Lively Atmosphere with Restaurants and Nightlife:**
#
# *   **Le Marais (3rd and 4th Arrondissements):** This trendy and historic area is known for its stylish boutiques, art galleries, vibrant bistros, and lively bars. It's often compared to New York's West Village and offers a quintessential Parisian experience.
# *   **Bastille (11th Arrondissement):** A popular spot for those seeking hip vibes without a premium price, Bastille offers a lively atmosphere with numerous bars, clubs, and restaurants.
# *   **Latin Quarter (5th Arrondissement):** This historic student district, centered around the Sorbonne, is full of energy with many attractions, appealing restaurants, and charming streets. It's also considered a safe and central area.
# *   **Oberkampf and République (11th Arrondissement):** Known for its "cool" factor, this area offers many incredible restaurants and a vibrant nightlife, with easy access to the rest of the city.
# *   **Pigalle (9th Arrondissement):** Famous for its nightlife, Pigalle is also home to trendy bars, coffee shops, and bakeries.
#
# **For Proximity to Attractions and Convenience:**
#
# *   **1st Arrondissement (Louvre, Tuileries):** This is the heart of Paris, home to major attractions like the Louvre Museum and Tuileries Garden. It's majestic and walkable, though it can be touristy and expensive.
# *   **7th Arrondissement (Eiffel Tower, Musée d'Orsay):** Ideal for those who want to be close to iconic landmarks like the Eiffel Tower and Musée d'Orsay. It also offers quieter residential pockets and is conveniently located for exploring other major sights.
# *   **6th Arrondissement (Saint-Germain-des-Prés):** This elegant and charming neighborhood is close to many attractions and offers a mix of literary history, high-end shops, and beautiful streets. It's considered a safe and desirable area.
#
# **For a Quieter, More Residential Feel:**
#
# *   **12th Arrondissement:** This area is quite residential and offers a peaceful atmosphere with proximity to green spaces like Bois de Vincennes and the Coulée Verte.
# *   **14th Arrondissement (Denfert-Rochereau):** Known for its village-like atmosphere and quiet streets, this is a popular residential area for locals, offering parks and good transportation links.
# *   **Île Saint-Louis:** A peaceful and charming island neighborhood located in the heart of Paris, adjacent to Île de la Cité.
#
# **For a Local Experience:**
#
# *   **Canal Saint-Martin (10th Arrondissement):** This area is popular for its relaxed vibe, charming cafés, wine bars, and local restaurants. It's considered a great spot for a more authentic Parisian experience.
#
# When choosing, consider how important being central is versus experiencing a more local, less touristy vibe, and of course, your budget.
#
# 👤 You: What are the best sites to visit nearby?
# 🤵 Martin: I can help you with that! To give you the best recommendations for nearby sites, could you tell me **which neighborhood in Paris you're considering staying in?**
#
# Once I know your general area, I can suggest the most convenient and exciting attractions close to you.
# 🤵 Martin: call recommendation_agent
# 🤵 Martin: To give you the best recommendations for nearby sites, please tell me which neighborhood in Paris you're considering staying in. Once I know your general area, I can suggest the most convenient and exciting attractions close to you.
# 🤵 Martin: I can help you with that! To give you the best recommendations for nearby sites, could you tell me **which neighborhood in Paris you're considering staying in?**
#
# Once I know your general area, I can suggest the most convenient and exciting attractions close to you.
# 🤵 Martin: To give you the best recommendations for nearby sites, could you please tell me which neighborhood in Paris you're considering staying in? Once I know your general area, I can suggest the most convenient and exciting attractions close to you.
#
# ============================================================
